# %%
#-ПОДКЛЮЧЕНИЕ-МОДУЛЕЙ-И-БИБЛИОТЕК-
# %matplotlib inline

import numpy              as np
import matplotlib.pyplot  as plt
import moviepy.editor     as mpy00
import scipy
import glob
import nbimporter
import math

from scipy                import sparse
from scipy.sparse         import linalg
from numpy                import pi, sin, cos, ma
from pylab                import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib           import cm
from matplotlib.ticker    import LinearLocator, FormatStrFormatter
from matplotlib           import animation

import SpaceDifferentiationOperators as SD 
import TimeDifferentiationOperators  as TD
import SchemeAnalysis                as SA

# %%
A = SA.ConvAnalyzer('Euler', 'leftPeriodic', 1)
A.SinTestConv(2, 10*(2**3), 20*(2**3), 1)

# %%
A = SA.ConvAnalyzer('RK4', 'SBP42SAT', 1)
A.SinTestConv(2, 10*(2**3), 20*(2**3), 1)
# Out:
# Order of Convergence: 4.054397201339887
# 16.61480206954702

# %%
cx1 = 10*(2**3)
ct1 = 20*(2**3)

cx2 = 10*(2**4)
ct2 = 20*(2**4)

x1 = np.arange(0 , cx1+1, dtype=double)*2*pi/cx1
x2 = np.arange(0 , cx2+1, dtype=double)*2*pi/cx2

D1 = SD.SBP42SAT(2*pi/cx1, 1, cx1+1)
D2 = SD.SBP42SAT(2*pi/cx2, 1, cx2+1)

T1 = TD.RK4(2*pi/ct1, D1)
T2 = TD.RK4(2*pi/ct2, D2)

PHI1 = np.zeros((ct1+1, cx1+1))
PHI2 = np.zeros((ct2+1, cx2+1))

PHI1[0] = sin(x1)
PHI2[0] = sin(x2)

T1.diff(PHI1)
T2.diff(PHI2)

A1 = SA.SchemeAnalyzer(T1,D1)
A2 = SA.SchemeAnalyzer(T2,D2)
A1.PrintCourantNumber()
A2.PrintCourantNumber()

Error1 = PHI1[-1] - sin(x1)
Error2 = PHI2[-1] - sin(x2)
# Out:
# Courant number: 0.5
# Courant number: 0.5

# %%
log2(sqrt(2*pi/cx1*Error1@Error1)/sqrt(2*pi/cx2*Error2@Error2))
# Out:
# 4.054397201339887

# %%
plt.plot(x1,PHI1[-1])
plt.plot(x1,sin(x1))
