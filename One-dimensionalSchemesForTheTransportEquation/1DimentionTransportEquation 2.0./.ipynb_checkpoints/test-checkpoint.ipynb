# %%
#-ПОДКЛЮЧЕНИЕ-МОДУЛЕЙ-И-БИБЛИОТЕК-
# %matplotlib inline

import numpy              as np
import scipy
import matplotlib.pyplot  as plt
import glob
import moviepy.editor     as mpy
import nbimporter
import math

from scipy                import sparse
from scipy.sparse         import linalg
from numpy                import pi, sin, cos, ma
from pylab                import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib           import cm
from matplotlib.ticker    import LinearLocator, FormatStrFormatter
from matplotlib           import animation

import SpaceDifferentiationOperators as SD 
import TimeDifferentiationOperators as TD
import SchemeAnalysis as SA

# %% [markdown]
# ------

# %%
basis = 2
num   = 8

A = SA.ApproxAnalyzer('Euler', 'LeftPeriodic')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])
    
plt.plot(ph,p)
plt.plot(ph, np.ones(ph.size))
# Out:
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5
# Courant number: 0.5

# %% [markdown]
# ------

# %%
basis = 2
num   = 8

A = SA.ApproxAnalyzer('RK4', 'LeftPeriodic')
l2Error = A.SinApprox(basis,num)

# %%
p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])

# %%
plt.plot(ph,p)
plt.plot(ph, np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 8

A = SA.ApproxAnalyzer('RK4', 'Center2Periodic')
l2Error = A.SinApprox(basis,num)

# %%
p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])

# %%
plt.plot(ph,p)
plt.plot(ph, 2*np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 8

A = SA.ApproxAnalyzer('RK4', 'Center4Periodic')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])
    
plt.plot(ph,p)
plt.plot(ph, 4*np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 7

A = SA.ApproxAnalyzer('RK4', 'SBP21PROJ')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])
    
plt.plot(ph,p)
plt.plot(ph, 2.5*np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 8

A = SA.ApproxAnalyzer('RK4', 'SBP42PROJ')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])
    
plt.plot(ph,p)
plt.plot(ph, 3.5*np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 7

A = SA.ApproxAnalyzer('RK4', 'SBP21SAT')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = log2(l2Error[i]/l2Error[i+1])
    
plt.plot(ph,p)
plt.plot(ph, 2.5*np.ones(ph.size))

# %% [markdown]
# ------

# %%
basis = 2
num   = 7

A = SA.ApproxAnalyzer('RK4', 'SBP42SAT')
l2Error = A.SinApprox(basis,num)

p = np.zeros(num-1)
ph = np.zeros(num-1)

for i in range(num-1):
    ph[i] = i
    p[i]  = math.log(l2Error[i]/l2Error[i+1], 2)
    
plt.plot(ph,p)

# %%
cx = 40
ct = 80
h = 2*pi/cx
tau = 2*pi/ct
x1  = np.arange(0 , cx + 1, dtype=double)*h
IC1 = sin(x1)

D1 = SD.SBP21SAT(h,1,cx+1)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx+1))
PHI1[0] = IC1

T1.diff(PHI1)

# %%
fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)

# %%
cx = 40
ct = 80
h = 2*pi/cx
tau = 2*pi/ct
x1  = np.arange(0 , cx + 1, dtype=double)*h
IC1 = sin(x1)

D1 = SD.SBP21PROJ(h,1,cx+1)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx+1))
PHI1[0] = IC1

T1.diff(PHI1)

# %%
fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)

# %%
cx = 40
ct = 80
h = 2/cx
tau = 2/ct
x1  = np.arange(0 , cx, dtype=double)*h
IC1 = exp((x-1)**2/2)

D1 = SD.Center2Periodic(h,1,cx)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx))
PHI1[0] = IC1

T1.diff(PHI1)

# %%
fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)

# %%
cx = 40
ct = 80
h = 2*pi/cx
tau = 2*pi/ct
x1  = np.arange(0 , cx + 1, dtype=double)*h
IC1 = sin(x1)

D1 = SD.SBP42SAT(h,1,cx+1)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx+1))
PHI1[0] = IC1

T1.diff(PHI1)

fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)

# %%
cx = 40
ct = 80
h = 2*pi/cx
tau = 2*pi/ct
x1  = np.arange(0 , cx + 1, dtype=double)*h
IC1 = sin(x1)

D1 = SD.SBP42PROJ(h,1,cx+1)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx+1))
PHI1[0] = IC1

T1.diff(PHI1)

fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)

# %%
cx = 40
ct = 80
h = 2*pi/cx
tau = 2*pi/ct
x1  = np.arange(0 , cx, dtype=double)*h
IC1 = sin(x1)

D1 = SD.Center4Periodic(h,1,cx)
T1 = TD.RK4(tau, D1)
PHI1 = np.zeros((ct+1,cx))
PHI1[0] = IC1

T1.diff(PHI1)

fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax[0].plot(x1,PHI1[-1]-IC1)
ax[1].plot(x1,PHI1[-1])
ax[1].plot(x1,IC1)
