# %%
#-ПОДКЛЮЧЕНИЕ-МОДУЛЕЙ-И-БИБЛИОТЕК-
# %matplotlib notebook

import numpy              as np
import matplotlib.pyplot  as plt
import moviepy.editor     as mpy00
import scipy
import glob
import nbimporter
import math

from scipy                import sparse
from scipy.sparse         import linalg
from numpy                import pi, sin, cos, ma
from pylab                import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib           import cm
from matplotlib.ticker    import LinearLocator, FormatStrFormatter
from matplotlib           import animation

import SpaceDifferentiationOperators as SD 
import TimeDifferentiationOperators  as TD
import SchemeAnalysis                as SA

# %%
xmax = 2*pi
tmax = 4*pi
cx   = 10
ct   = 200

x      = np.arange(0 , cx,   dtype=double)*xmax/cx
t      = np.arange(0 , ct+1, dtype=double)*tmax/ct
PHI    = np.zeros((ct+1,cx))
PHI[0] = sin(x)

D = SD.Left3Periodic(xmax/cx, 1, cx)
T = TD.RK4(tmax/ct, D)
T.diff(PHI)

# %%
A = SA.ConvAnalyzer('RK4','Left3Periodic',1)
A.SinTestConv(2, 2**3, 20*2**3, 1)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Order of Convergence: 2.4638521022992483
# 5.516878096253493

# %%
#-ВИЗУАЛИЗАЦИЯ-
fig, ax = plt.subplots()
plt.style.use('dark_background')
surf = ax.plot(x,PHI[0])

def animate(n):
    plt.style.use('dark_background')
    ax.clear()
    ax.set_ylim(-2,2)
    surf = ax.plot(x,PHI[n])
    return surf

anim = animation.FuncAnimation(fig, animate, frames=len(t), interval=1, repeat = False)
# Out:
# <img src="data:image/png;base64,..." width="640">
