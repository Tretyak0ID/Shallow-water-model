# %%
#-ПОДКЛЮЧЕНИЕ-МОДУЛЕЙ-И-БИБЛИОТЕК-
# %matplotlib notebook

import numpy              as np
import matplotlib.pyplot  as plt
import moviepy.editor     as mpy00
import scipy
import glob
import nbimporter
import math

from scipy                import sparse
from scipy.sparse         import linalg
from numpy                import pi, sin, cos, ma
from pylab                import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib           import cm
from matplotlib.ticker    import LinearLocator, FormatStrFormatter
from matplotlib           import animation

import SpaceDifferentiationOperators as SD 
import TimeDifferentiationOperators  as TD
import SchemeAnalysis                as SA
import MeshBlocksMethods         as MBM

# %%
### -ВИЗУАЛИЗАЦИЯ-
fig, ax = plt.subplots()
plt.style.use('dark_background')
surf = ax.plot(X,PHI[0])

def animate(n):
    plt.style.use('dark_background')
    ax.clear()
    ax.set_ylim(-2,2)
    surf = ax.plot(X,PHI[n])
    return surf

anim = animation.FuncAnimation(fig, animate, frames=ct+1, interval=1, repeat = False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = SA.SBPAnalyzer(T,D)
C = SA.ConvAnalyzer('RK4','SBP21SAT_2',1)

# %%
C.SinTestConv(2, 50, 100, 1, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 C.SinTestConv(2, 50, 100, 1, 2)
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0./SchemeAnalysis.py:168, in ConvAnalyzer.SinTestConv(self, base, fcx, fct, tnum, coef)
#     166 for i in range(fct+1):
#     167     T1.diff(PHI1)
# --> 168     T2.diff(PHI2)
#     170 Error1 = PHI1[-1] - sin(x1)
#     171 Error2 = PHI2[-1] - sin(x2)
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0./TimeDifferentiationOperators.py:28, in TimeDiff.diff(self, f)
#      25 def diff(self, f):
#      26     #полное дифференцирование по времени
#      27     for j in range(f[:,0].size-1):
# ---> 28         f[j+1,:] = self.make_step(f[j,:])
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0./TimeDifferentiationOperators.py:54, in RK4.make_step(self, f)
#      53 def make_step(self, f):
# ---> 54     f1 = -self.space_operator.diff(f)
#      55     f2 = -self.space_operator.diff(f1)
#      56     f3 = -self.space_operator.diff(f2)
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0./SpaceDifferentiationOperators.py:325, in SBP21SAT_2BLOCKS.diff(self, f)
#     324 def diff(self, f):
# --> 325     return self.v*(self.matrix@f + np.linalg.solve(self.H(),self.SAT(f)))
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0./SpaceDifferentiationOperators.py:209, in SBP21_2BLOCKS.H(self)
#     207 def H(self):
#     208     Opl = SBP21(self.hl,self.v,self.sizel)
# --> 209     Opr = SBP21(self.hr,self.v,self.sizer)
#     210     Hl  = Opl.H()
#     211     Hr  = Opr.H()
#
# File ~/Документы/DynamicCoreOfTheAtmosphereModel/One-dimensionalSchemesForTheTransportEquation/1DimentionTransportEquation 2.0
#        3.46944695e-18, 1.08420217e-16, 1.40512602e-16, 5.55111512e-17,
#        3.46944695e-18, 4.97038933e-17, 3.04660810e-17, 4.33680869e-18,
#        1.31838984e-16, 7.80625564e-17, 8.06646416e-17, 4.51028104e-17,
#        1.16226473e-16, 1.77809156e-16, 4.68375339e-17, 5.37764278e-17,
#        4.68375339e-17, 1.05818132e-16, 1.59594560e-16, 8.67361738e-17,
#        4.85722573e-17, 8.84708973e-17, 5.37764278e-17, 1.05818132e-16,
#        4.51028104e-17, 7.97972799e-17, 2.25514052e-17, 2.94902991e-17,
#        4.33680869e-17, 3.12250226e-17, 4.85722573e-17, 1.73472348e-17,
#        5.72458747e-17, 2.77555756e-17, 7.28583860e-17, 3.81639165e-17,
#        1.28369537e-16, 8.67361738e-18, 6.93889390e-18, 1.26634814e-16,
#        9.88792381e-17, 3.29597460e-17, 2.02962647e-16, 9.88792381e-17,
#        1.11022302e-16, 3.12250226e-17, 3.29597460e-17, 2.68882139e-17,
#        4.33680869e-17, 4.25007252e-17, 2.86229374e-17, 1.82145965e-17,
#        4.72712147e-17, 2.10768902e-16, 4.55364912e-18, 3.92616712e-17,
#        5.17164436e-17, 4.92227786e-17, 7.76288755e-17, 5.89805982e-17,
#        3.72965547e-17, 1.07552856e-16, 9.97465999e-17, 3.29597460e-17,
#        8.67361738e-17, 1.73472348e-17, 9.19403442e-17, 3.46944695e-18,
#        8.15320034e-17, 2.25514052e-17, 1.07552856e-16, 6.93889390e-18,
#        1.38777878e-17, 8.84708973e-17, 1.38777878e-17, 7.80625564e-17,
#        5.20417043e-18, 6.93889390e-18, 1.73472348e-17, 4.16333634e-17,
#        5.20417043e-17])

# %% [markdown]
# ## SIN

# %%
xmax = 2*pi
sep  = pi
cxl  = 2**4
cxr  = 2**5

tmax = 2*pi
ct   = 2**5

D = SD.SBP21SAT_2BLOCKS(sep/cxl, (xmax-sep)/cxr, cxl+1, cxr+1, 1)
T = TD.RK4(tmax/ct, D)
BI = MBM.Block2Mesh(cxl, cxr, 0, xmax, sep,ct)
BI.DefineIC(sin(BI.blockl.mesh), sin(BI.blockr.mesh))
X,PHI = BI.GetFullSolution()
T.diff(PHI)
Error1 = PHI[-1] - sin(X)

# %%
xmax = 2*pi
sep  = pi
cxl  = 2**5
cxr  = 2**6

tmax = 2*pi
ct   = 2**6

D = SD.SBP21SAT_2BLOCKS(sep/cxl, (xmax-sep)/cxr, cxl+1, cxr+1, 1)
T = TD.RK4(tmax/ct, D)
BI = MBM.Block2Mesh(cxl, cxr, 0, xmax, sep,ct)
BI.DefineIC(sin(BI.blockl.mesh), sin(BI.blockr.mesh))
X,PHI = BI.GetFullSolution()
T.diff(PHI)
Error2 = PHI[-1] - sin(X)

# %%
sqrt(Error1@Error1)/sqrt(Error2@Error2)
# Out:
# 2.9143109468331816

# %% [markdown]
# ## Gauss

# %%
xmax = 2
sep  = 1
cxl  = 2**4
cxr  = 2**5

tmax = 2
ct   = 2**5

D = SD.SBP21SAT_2BLOCKS(sep/cxl, (xmax-sep)/cxr, cxl+1, cxr+1, 1)
T = TD.RK4(tmax/ct, D)
BI = MBM.Block2Mesh(cxl, cxr, 0, xmax, sep,ct)
BI.DefineIC(exp(-(BI.blockl.mesh-1)**2/0.05), exp(-(BI.blockr.mesh-1)**2/0.05))
X,PHI = BI.GetFullSolution()
T.diff(PHI)
Error1 = PHI[-1] - exp(-(X-1)**2/0.05)

# %%
xmax = 2
sep  = 1
cxl  = 2**5
cxr  = 2**6

tmax = 2
ct   = 2**6

D = SD.SBP21SAT_2BLOCKS(sep/cxl, (xmax-sep)/cxr, cxl+1, cxr+1, 1)
T = TD.RK4(tmax/ct, D)
BI = MBM.Block2Mesh(cxl, cxr, 0, xmax, sep,ct)
BI.DefineIC(exp(-(BI.blockl.mesh-1)**2/0.05), exp(-(BI.blockr.mesh-1)**2/0.05))
X,PHI = BI.GetFullSolution()
T.diff(PHI)
Error2 = PHI[-1] - exp(-(X-1)**2/0.05)

# %%
sqrt(Error1@Error1)/sqrt(Error2@Error2)
# Out:
# 2.529603039186616

# %%
### -ВИЗУАЛИЗАЦИЯ-
fig, ax = plt.subplots()
plt.style.use('dark_background')
surf = ax.plot(X,PHI[0])

def animate(n):
    plt.style.use('dark_background')
    ax.clear()
    ax.set_ylim(-2,2)
    surf = ax.plot(X,PHI[n])
    return surf

anim = animation.FuncAnimation(fig, animate, frames=ct+1, interval=1, repeat = False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## ---T---

# %%
xmax = 2
sep  = 1
cxl  = 2**6
cxr  = 2**7

tmax = 4
ct   = 2**8

D = SD.SBP21SAT_2BLOCKS(sep/cxl, (xmax-sep)/cxr, cxl+1, cxr+1, 1)
T = TD.RK4(tmax/ct, D)
BI = MBM.Block2Mesh(cxl, cxr, 0, xmax, sep,ct)
IC1 = np.zeros(BI.blockl.mesh.size)
IC1[-10:] = np.ones(1)
IC2 = np.zeros(BI.blockr.mesh.size)
IC2[:10] = np.ones(10)
BI.DefineIC(IC1,IC2)
X,PHI = BI.GetFullSolution()
T.diff(PHI)
Error1 = PHI[-1] - exp(-(X-1)**2/0.05)

# %%
### -ВИЗУАЛИЗАЦИЯ-
fig, ax = plt.subplots()
plt.style.use('dark_background')
surf = ax.plot(X,PHI[0])

def animate(n):
    plt.style.use('dark_background')
    ax.clear()
    ax.set_ylim(-2,2)
    surf = ax.plot(X,PHI[n])
    return surf

anim = animation.FuncAnimation(fig, animate, frames=ct+1, interval=1, repeat = False)
# Out:
# <img src="data:image/png;base64,..." width="640">
