# %% [markdown]
# # GEOSTROPHIC BALANCE

# %%
# %load_ext autoreload
# %autoreload 2

from state              import State
from domain             import Domain
from swe_operators      import SweAdvectiveFormOperator, SweVecInvFormOperator
from time_schemes       import rk4
from initial_conditions import gaussian_hill, barotropic_instability, stream_geostrophic_balance, \
                               eddy_geostrophic_balance, eddy_full_geostrophic_balance, eddy_and_velocity_geostrophic_balance
import operators as op
from vizualization      import trisurf_field, animate_trisurf, surf_interpolated_field, animate_interpolated_surf, \
                               animate_tripcolor, tripcolor_field, imshow_interpolated_field

import numpy as np
from vecmath import calc_mass, calc_c_norm
# %matplotlib notebook

# %%
# definition of computational domain constants
RADZ = 6371.22 * 1000.0 # "Earth" radii in meters
GRAV = 9.80616 # "Earth" gravity acceleration in m * s**(-2)
OMEGA = 7.292 * 10**(-5) # "Earth" angular velocity in rad * s**(-1)
PCORI = 2 * OMEGA # Coriolis parameter
H_MEAN = 10 * 1000.0 # "Earth" mean atmosphere depth
C_GRAV = np.sqrt(GRAV * H_MEAN) # Gravity wave speed
LX = 2 * np.pi * RADZ # domain size [0, LX] x [0, LY]
LY = 2 * np.pi * RADZ # domain size [0, LX] x [0, LY]

# %% [markdown]
# ### 1. Без учета коспонент скорости

# %%
# %%time
import time
from IPython.display import display, clear_output

domains = [Domain(xs = 0.0,    xe = LX / 2, nx = 64, ys = 0.0, ye = LY, ny = 128,  lx=LX, ly=LY), \
           Domain(xs = LX / 2, xe = LX    , nx = 32, ys = 0.0, ye = LY, ny = 64,  lx=LX, ly=LY)]

state = eddy_geostrophic_balance(domains, pcori = PCORI, g = GRAV, h_mean = H_MEAN, scale_h = 22 * 10.0 ** -3, scale_sigma = 10.0 ** 6, xc = LX / 4)
swe_operator = SweVecInvFormOperator(g=GRAV, pcori=PCORI, diff_method = op.diff_sbp42)

T  = 8 * 24 * 3600
Nt = 8 * 150
dt = T / Nt

states_list = [state]
for k in range(Nt+1):
    clear_output(wait=True)
    display('Time step '+ str(k))
    state = rk4(state, swe_operator, dt, domains)
    states_list.append(state)
# Out:
# 'Time step 1200'
# CPU times: user 40.3 s, sys: 785 ms, total: 41.1 s
# Wall time: 40.1 s

# %%
h_list = [state.h for state in states_list]
animate_trisurf(h_list, domains, 4)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
c_norms = np.empty([])

for i in range(np.size(states_list)):
    c_norms = np.append(c_norms, calc_c_norm(states_list[0].h-states_list[i].h, domains))
plt.plot(c_norms)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### С учетом компонент вектора скорости в уравнениях
# 1. На сгущенном блоке

# %%
# %%time
import time
from IPython.display import display, clear_output

domains = [Domain(xs = 0.0,    xe = LX / 2, nx = 128, ys = 0.0, ye = LY, ny = 256,  lx=LX, ly=LY), \
           Domain(xs = LX / 2, xe = LX    , nx = 64, ys = 0.0, ye = LY, ny = 128,  lx=LX, ly=LY)]

state = eddy_full_geostrophic_balance(domains, pcori = PCORI, g = GRAV, h_mean = H_MEAN, scale_h = 22 * 10.0 ** -3, scale_sigma = 10.0 ** 6, xc = LX / 4)
swe_operator = SweVecInvFormOperator(g=GRAV, pcori=PCORI, diff_method = op.diff_sbp42)

T  = 8 * 24 * 3600
Nt = 8 * 150
dt = T / Nt

states_list = [state]
for k in range(Nt+1):
    clear_output(wait=True)
    display('Time step '+ str(k))
    state = rk4(state, swe_operator, dt, domains)
    states_list.append(state)
# Out:
# 'Time step 1200'
# CPU times: user 1min 21s, sys: 715 ms, total: 1min 22s
# Wall time: 1min 21s

# %%
h_list = [state.h for state in states_list]
animate_trisurf(h_list, domains, 4)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
c_norms = np.empty([])

for i in range(np.size(states_list)):
    c_norms = np.append(c_norms, calc_c_norm(states_list[0].h-states_list[i].h, domains))
plt.plot(c_norms)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 2. На блоке с низким разрешением

# %%
# %%time
import time
from IPython.display import display, clear_output

domains = [Domain(xs = 0.0,    xe = LX / 2, nx = 128, ys = 0.0, ye = LY, ny = 256,  lx=LX, ly=LY), \
           Domain(xs = LX / 2, xe = LX    , nx = 64, ys = 0.0, ye = LY, ny = 128,  lx=LX, ly=LY)]

state = eddy_full_geostrophic_balance(domains, pcori = PCORI, g = GRAV, h_mean = H_MEAN, scale_h = 22 * 10.0 ** -3, scale_sigma = 10.0 ** 6, xc = 3 * LX / 4)
swe_operator = SweVecInvFormOperator(g=GRAV, pcori=PCORI, diff_method = op.diff_sbp42)

T  = 8 * 24 * 3600
Nt = 8 * 150
dt = T / Nt

states_list = [state]
for k in range(Nt+1):
    clear_output(wait=True)
    display('Time step '+ str(k))
    state = rk4(state, swe_operator, dt, domains)
    states_list.append(state)
# Out:
# 'Time step 1200'
# CPU times: user 1min 19s, sys: 440 ms, total: 1min 20s
# Wall time: 1min 19s

# %%
h_list = [state.h for state in states_list]
animate_trisurf(h_list, domains, 4)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
c_norms = np.empty([])

for i in range(np.size(states_list)):
    c_norms = np.append(c_norms, calc_c_norm(states_list[0].h - states_list[i].h, domains))
plt.plot(c_norms)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Геострофический баланс в постоянном поле скорости

# %%
# %%time
import time
from IPython.display import display, clear_output

domains = [Domain(xs = 0.0,    xe = LX / 2, nx = 128, ys = 0.0, ye = LY, ny = 256,  lx=LX, ly=LY), \
           Domain(xs = LX / 2, xe = LX    , nx = 64, ys = 0.0, ye = LY, ny = 128,  lx=LX, ly=LY)]

state = eddy_and_velocity_geostrophic_balance(domains, pcori = PCORI, g = GRAV, h_mean = H_MEAN, scale_h = 22 * 10.0 ** -3, scale_sigma = 10.0 ** 6, xc = 1.5 * LX / 4)
swe_operator = SweVecInvFormOperator(g=GRAV, pcori=PCORI, diff_method = op.diff_sbp42)

T  = 4 * 24 * 3600
Nt = 4 * 150
dt = T / Nt

states_list = [state]
for k in range(Nt+1):
    clear_output(wait=True)
    display('Time step '+ str(k))
    state = rk4(state, swe_operator, dt, domains)
    states_list.append(state)
# Out:
# 'Time step 0'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File <timed exec>:18, in <module>
#
# File ~/Documents/INM RAS/DynamicCoreOfTheAtmosphereModel/2dSWMMultiblock/time_schemes.py:6, in rk4(state, operator, dt, domain)
#       5 def rk4(state, operator, dt, domain):
# ----> 6     k1 = operator.calc_rhs(state, domain)
#       7     k2 = operator.calc_rhs(state + dt / 2 * k1, domain)
#       8     k3 = operator.calc_rhs(state + dt / 2 * k2, domain)
#
# File ~/Documents/INM RAS/DynamicCoreOfTheAtmosphereModel/2dSWMMultiblock/swe_operators.py:29, in SweVecInvFormOperator.calc_rhs(self, state, domains)
#      28 def calc_rhs(self, state, domains):
# ---> 29     div = op.calc_div(state.h * state.u, state.h * state.v, domains, self.diff_method)
#      31     kin_energy = (state.u * state.u + state.v * state.v) * 0.5
#      32     gx, gy = op.calc_grad(self.g * state.h + kin_energy, domains, self.diff_method)
#
# File ~/Documents/INM RAS/DynamicCoreOfTheAtmosphereModel/2dSWMMultiblock/operators.py:21, in calc_div(u, v, domains, diff_method)
#      19     div_x[ind] = diff_method(u[ind], 'x', domain)
#      20     div_y[ind] = diff_method(v[ind], 'y', domain)
# ---> 21 return sbp_SAT_penalty_two_block(div_x, u, 'x', domains, diff_method.__name__) + \
#      22        sbp_SAT_penalty_two_block(div_y, v, 'y', domains, diff_method.__name__)
#
# File ~/Documents/INM RAS/DynamicCoreOfTheAtmosphereModel/2dSWMMultiblock/operators.py:103, in sbp_SAT_penalty_two_block(tend, f, direction, domains, diff_method_name)
#     101         interp_method = interp_1d_sbp42_2to1_ratio
#     102     else:
# --> 103         raise Exception(f"Error in sbp_SAT_penalty_two_block. Unknown resolution ratio!")
#     105 if direction == 'x':
#     106
#     107     # SAT in x direction (assuming two blocks in x direction)
#     108     ff = interp_method(f[1][:, 0], "coarse2fine")
#
# Exception: Error in sbp_SAT_penalty_two_block. Unknown resolution ratio!

# %%
curl_list = [op.calc_curl(state.u, state.v, domains, op.diff_sbp42) for state in states_list]

# %%
animate_tripcolor(curl_list, domains, 100)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
h_list = [state.h for state in states_list]
animate_tripcolor(h_list, domains, 100)
# Out:
# <img src="data:image/png;base64,..." width="800">
